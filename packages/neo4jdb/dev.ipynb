# %%
from neo4j import GraphDatabase
from dotenv import load_dotenv
load_dotenv()
import os
from neomodel import (config, StructuredNode, StringProperty, IntegerProperty,
    UniqueIdProperty, RelationshipTo)
from pylib.constants import NEO4J_DATABASE_URL
from pylib.ogm import AwesomeList, Repo

# %%
NEO4J_DATABASE_URL
# Out:
# 'neo4j+s://neo4j:WtxpaB3XtVK0VgTcecmT4PKRcWi4SRU4XSqvKNu_YLQ@aea6d15a.databases.neo4j.io'

# %%
config.DATABASE_URL = NEO4J_DATABASE_URL

# %%
repo = Repo.nodes.get(url="https://github.com/CrossCopy/tauri-plugin-clipboard")

# %%
repo.awesomeList.__dict__
# Out:
# {'source': <Repo: {'uid': 'b1589624fb9a40179197eb10b91fef25', 'owner': 'CrossCopy', 'name': 'tauri-plugin-clipboard', 'stars': 137, 'url': 'https://github.com/CrossCopy/tauri-plugin-clipboard', 'updated_at': datetime.datetime(2024, 8, 15, 9, 58, 39, 755930, tzinfo=<UTC>), 'created_at': datetime.datetime(2024, 8, 15, 9, 58, 39, 755940, tzinfo=<UTC>), 'missing': False, 'description': 'A Tauri clipboard plugin with text, files, html, RTF, and image support. Clipboard content update monitoring is also supported. ', 'diskUsage': 3530, 'forkCount': 8, 'hasSponsorshipsEnabled': True, 'homepageUrl': 'https://crosscopy.github.io/tauri-plugin-clipboard/', 'license': 'mit', 'licenseInfo': {'key': 'mit', 'name': 'MIT License', 'nickname': None}, 'openIssuesCount': 1, 'pullRequestsCount': 12, 'releasesCount': 9, 'repoPushedAt': datetime.datetime(2024, 8, 9, 7, 2, 53, tzinfo=<UTC>), 'repoUpdatedAt': datetime.datetime(2024, 8, 14, 20, 11, 21, tzinfo=<UTC>), 'repoCreatedAt': datetime.datetime(2023, 1, 19, 7, 20, 1, tzinfo=<UTC>), 'watchersCount': 4, 'createdAt': datetime.datetime(2024, 8, 14, 18, 41, 5, 475000, tzinfo=<UTC>), 'element_id_property': '4:aac3f541-7c55-4358-acc4-9908772efece:243'}>,
#  'source_class': pylib.ogm.Repo,
#  'name': 'awesomeList',
#  'definition': {'relation_type': 'IN_AWESOME_LIST',
#   'direction': 1,
#   'model': None,
#   'node_class': pylib.ogm.AwesomeList}}

# %%
neorepos = Repo.nodes.all()

# %%
neorepo_urls = [node.url for node in neorepos]

# %%
neourl_set = set(neorepo_urls)
# Out:
# ['https://github.com/peterroe/vue-img-lazy-tiny',
#  'https://github.com/gbast0s/vue3-ui-preloader',
#  'https://github.com/zero-one-code/vue-default-page',
#  'https://github.com/hilongjw/vue-progressbar',
#  'https://github.com/BosNaufal/vue2-loading-bar',
#  'https://github.com/dalphyx/vue-top-progress',
#  'https://github.com/vue-bulma/nprogress',
#  'https://github.com/websmurf/vue-progress-button',
#  'https://github.com/dzwillia/vue-simple-progress',
#  'https://github.com/val-bubbleflat/vue-component-loading',
#  'https://github.com/spemer/vue-scroll-progress',
#  'https://github.com/ajerez/vue-read-progress',
#  'https://github.com/dreambo8563/easy-circular-progress',
#  'https://github.com/LucasLeandro1204/vue-twitter-counter',
#  'https://github.com/meloalright/vue-ins-progress-bar',
#  'https://github.com/jambonn/vue-next-progressbar',
#  'https://github.com/marcoschulte/vue3-progress',
#  'https://github.com/rofixro/css-3d-progress',
#  'https://github.com/Akryum/vue-tooltip',
#  'https://github.com/antongorodezkiy/vue-popper-component',
#  'https://github.com/hekigan/vue-directive-tooltip',
#  'https://github.com/RobinCK/vue-popper',
#  'https://github.com/jambonn/vue-popper-lite',
#  'https://github.com/cpfarher/vue-tooltipster',
#  'https://github.com/ChristianKienle/k-pop',
#  'https://github.com/adamdehaven/vue-custom-tooltip',
#  'https://github.com/iendeavor/vue-use-popperjs',
#  'https://github.com/gVguy/vue-follow-tooltip',
#  'https://github.com/javisperez/vuedals',
#  'https://github.com/adeptoas/sweet-modal-vue',
#  'https://github.com/euvl/vue-js-modal',
#  'https://github.com/Egorvah/vudal',
#  'https://github.com/chenjiahan/vodal',
#  'https://github.com/pexea12/vue-image-lightbox',
#  'https://github.com/mazipan/vue2-simplert',
#  'https://github.com/David-Desmaisons/Vue-Semantic-Modal',
#  'https://github.com/crowdbotics/v-img',
#  'https://github.com/emiliorizzo/vue-dialog-drag',
#  'https://github.com/qgp9/vue-ya-semantic-modal',
#  'https://github.com/DCzajkowski/vue-pure-lightbox',
#  'https://github.com/mirari/v-viewer',
#  'https://github.com/fengyuanchen/viewerjs',
#  'https://github.com/zhangxiang958/vue-messageBox',
#  'https://github.com/Godofbrowser/vuejs-dialog',
#  'https://github.com/michitaro/vue-window',
#  'https://github.com/RobinCK/vue-gallery',
#  'https://github.com/anteriovieira/vue-swal',
#  'https://github.com/hjkcai/vue-modal-dialogs',
#  'https://github.com/la7ender/vue-img-view',
#  'https://github.com/davodaslanifakor/modaltor',
#  'https://github.com/nash403/v-modal-backdrop',
#  'https://github.com/dillonchanis/vue-cute-modal',
#  'https://github.com/TerryZ/v-dialogs',
#  'https://github.com/KitchenStories/vue-gallery-slideshow',
#  'https://github.com/morkro/vue-a11y-dialog',
#  'https://github.com/officert/vue-slideout-panel',
#  'https://github.com/TerryZ/v-gallery',
#  'https://github.com/leepyng/vue2-image-loader',
#  'https://github.com/am283721/vue-my-photos',
#  'https://github.com/nikli2009/vue-img-orientation-changer',
#  'https://github.com/adileo/vue-topmodal',
#  'https://github.com/MelMacaluso/vue-modal',
#  'https://github.com/Innologica/vue-stackable-modal',
#  'https://github.com/avil13/vue-sweetalert2',
#  'https://github.com/ovictorpereira/vue-modality',
#  'https://github.com/NickKaramoff/vue-tinybox',
#  'https://github.com/andrewvasilchuk/vue-accessible-modal',
#  'https://github.com/yariksav/vuetify-dialog',
#  'https://github.com/behawesometw/vue-hawesome-modal',
#  'https://github.com/XeniacDev/xmodal',
#  'https://github.com/kouts/vue-modal',
#  'https://github.com/hunterliu1003/vue-final-modal',
#  'https://github.com/altrusl/vuesence-modal-window',
#  'https://github.com/haiafara/vue-it-bigger',
#  'https://github.com/malekim/v3confirm',
#  'https://github.com/rlemaigre/vue3-promise-dialog',
#  'https://github.com/headmandev/vue3-side-panel',
#  'https://github.com/harmyderoman/vuejs-confirm-dialog',
#  'https://github.com/kolirt/vue-modal',
#  'https://github.com/webdevnerdstuff/vuetify-resize-drawer',
#  'https://github.com/vue-comps/vue-parallax',
#  'https://github.com/apertureless/vue-parallax',
#  'https://github.com/Aminerman/vue-mouse-parallax',
#  'https://github.com/jsnanigans/vue-parallax-js',
#  'https://github.com/aarcoraci/vue-parallax-view',
#  'https://github.com/Justineo/vue-awesome',
#  'https://github.com/robcresswell/vue-material-design-icons',
#  'https://github.com/ganl/vue-icon-font',
#  'https://github.com/mazipan/vue-ionicons',
#  'https://github.com/paulcollett/vue-ico',
#  'https://github.com/therufa/mdi-vue',
#  'https://github.com/FortAwesome/vue-fontawesome',
#  'https://github.com/nash403/g-icon',
#  'https://github.com/nkoik/vue-simple-line-icons',
#  'https://github.com/P3trur0/vue-country-flag',
#  'https://github.com/Lt0/vicon',
#  'https://github.com/IPRIT/md-svg-vue',
#  'https://github.com/qWici/vue-lang-code-flags',
#  'https://github.com/TerryMooreII/vue-zondicons',
#  'https://github.com/antonreshetov/vue-eva-icons',
#  'https://github.com/antonreshetov/vue-unicons',
#  'https://github.com/Cweili/vue-fa',
#  'https://github.com/man15h/vue-cryptoicon',
#  'https://github.com/matschik/vue-hero-icons',
#  'https://github.com/refactoringui/heroicons',
#  'https://github.com/tauri-apps/create-tauri-app',
#  'https://github.com/maximegris/angular-tauri',
#  'https://github.com/NicolaSpadari/nuxtor',
#  'https://github.com/charlesxsh/tauri-angular-boilerplate',
#  'https://github.com/HuakunShen/tauri-astro-template',
#  'https://github.com/RoseBlume/Bishop-Tauri-Template',
#  'https://github.com/rome-user/tauri-clojurescript-template',
#  'https://github.com/marc2332/tauri-deno-starter',
#  'https://github.com/kvnxiao/tauri-nextjs-template',
#  'https://github.com/HuakunShen/tauri-nuxt-template',
#  'https://github.com/Alfredoes234/tauri-preact-rsbuild-template',
#  'https://github.com/elibroftw/modern-desktop-app-template',
#  'https://github.com/henrhie/tauri-react-parcel-template',
#  'https://github.com/JonasKruckenberg/tauri-rescript-template',
#  'https://github.com/AR10Dev/tauri-solid-ts-tailwind-vite',
#  'https://github.com/probablykasper/tauri-svelte-template',
#  'https://github.com/deid84/tauri-sveltekit-admin-template',
#  'https://github.com/JonasKruckenberg/tauri-sycamore-template',
#  'https://github.com/Uninen/tauri-vue-template',
#  'https://github.com/skymen/tauri-vue-template',
#  'https://github.com/rgilsimoes/Tauronic/',
#  'https://github.com/tauri-apps/tauri-plugin-authenticator',
#  'https://github.com/tauri-apps/tauri-plugin-log',
#  'https://github.com/tauri-apps/tauri-plugin-sql',
#  'https://github.com/tauri-apps/tauri-plugin-store',
#  'https://github.com/tauri-apps/tauri-plugin-stronghold',
#  'https://github.com/tauri-apps/tauri-plugin-window-state',
#  'https://github.com/tauri-apps/window-vibrancy',
#  'https://github.com/tauri-apps/window-shadows',
#  'https://github.com/JonasKruckenberg/tauri-plugin-positioner',
#  'https://github.com/JonasKruckenberg/tauri-plugin-graphql',
#  'https://github.com/timfish/sentry-tauri',
#  'https://github.com/aptabase/tauri-plugin-aptabase',
#  'https://github.com/CrossCopy/tauri-plugin-clipboard',
#  'https://github.com/MatsDK/TauRPC',
#  'https://github.com/c2r0b/tauri-plugin-context-menu',
#  'https://github.com/HuakunShen/tauri-plugin-network',
#  'https://github.com/deid84/tauri-plugin-serialport',
#  'https://github.com/HuakunShen/tauri-plugin-system-info',
#  'https://github.com/wyhaya/tauri-plugin-theme',
#  'https://github.com/ahkohd/tauri-awesome-rpc',
#  'https://github.com/ahkohd/tauri-nspanel',
#  'https://github.com/pevers/tauri-plugin-nosleep/',
#  'https://github.com/astrodon/astrodon',
#  'https://github.com/oscartbeaumont/tauri-specta',
#  'https://github.com/persiliao/axios-tauri-api-adapter',
#  'https://github.com/probablykasper/svelte-tauri-filedrop',
#  'https://github.com/ahkohd/tauri-macos-menubar-app-example',
#  'https://github.com/ahkohd/tauri-macos-spotlight-example',
#  'https://github.com/KilleenCode/tauri-update-cloudflare',
#  'https://github.com/amrbashir/vite-plugin-tauri',
#  'https://github.com/mmpneo/curses',
#  'https://github.com/lzdyes/douyin-downloader',
#  'https://github.com/idootop/feiyu-player',
#  'https://github.com/jellyfin/jellyfin-vue',
#  'https://github.com/meel-hd/lofi-engine',
#  'https://github.com/Trivernis/mediarepo',
#  'https://github.com/probablykasper/mr-tagger',
#  'https://github.com/basharovV/musicat',
#  'https://github.com/louis030195/screen-pipe',
#  'https://github.com/xgetter-team/xgetter',
#  'https://github.com/gaeljacquin/yt-dlp-gui',
#  'https://github.com/Bin-Huang/chatbox',
#  'https://github.com/lencx/ChatGPT',
#  'https://github.com/Poordeveloper/chatgpt-app',
#  'https://github.com/Synaptrix/ChatGPT-Desktop',
#  'https://github.com/0xfrankz/Kaas',
#  'https://github.com/taecontrol/orion',
#  'https://github.com/dubisdev/quickgpt',
#  'https://github.com/rajatkulkarni95/yack',
#  'https://github.com/matthias-stemmler/annimate',
#  'https://github.com/fuyoo/bs-redis-desktop-client',
#  'https://github.com/geek-fun/dockit',
#  'https://github.com/l1xnan/duckling',
#  'https://github.com/ahqsoftwares/tauri-ahq-store',
#  'https://github.com/zenoxs/tauri-appcenter-companion',
#  'https://github.com/francesco-gaglione/AppHub',
#  'https://github.com/HuakunShen/devclean',
#  'https://github.com/fosslife/devtools-x',
#  'https://github.com/egoist/dropcode',
#  'https://github.com/zsmatrix62/echoo-app',
#  'https://github.com/colinlienard/gitlight',
#  'https://github.com/keadex/keadex',
#  'https://github.com/hcavarsan/kftray',
#  'https://github.com/Web3-Builders-Alliance/soda',
#  'https://github.com/tw93/Pake',
#  'https://github.com/Ironclad/rivet',
#  'https://github.com/dedSyn4ps3/tauri-mobile-test',
#  'https://github.com/chezhe/aleph',
#  'https://github.com/KM8Oz/BULKUS',
#  'https://github.com/zhanglun/lettura',
#  'https://github.com/mdSilo/mdSilo-app',
#  'https://github.com/enassi/enassi',
#  'https://github.com/HuakunShen/ezup',
#  'https://github.com/naaive/orange',
#  'https://github.com/spacedriveapp/spacedrive',
#  'https://github.com/adileo/squirreldisk',
#  'https://github.com/probablykasper/time-machine-inspector',
#  'https://github.com/kimlimjustin/xplorer',
#  'https://github.com/Orbitale/Compotes',
#  'https://github.com/Rabbit-Company/CryptoBal-Desktop',
#  'https://github.com/matthias-wright/ghorbu-wallet',
#  'https://github.com/ustaxes/ustaxes',
#  'https://github.com/wearrrrr/9Launcher',
#  'https://github.com/Tnze/ffxiv-best-craft',
#  'https://github.com/zelytra/BetterFleet',
#  'https://github.com/philipborg/CubeShuffle',
#  'https://github.com/franciscoBSalgueiro/en-croissant',
#  'https://github.com/fishfight/FishLauncher',
#  'https://github.com/open-goal/launcher',
#  'https://github.com/ow-mods/ow-mod-man',
#  'https://github.com/Raphiiko/OyasumiVR',
#  'https://github.com/raicuparta/rai-pal',
#  'https://github.com/Gawdl3y/Resolute',
#  'https://github.com/Tormak9970/Steam-Art-Manager',
#  'https://github.com/jamessizeland/tauri-chess',
#  'https://github.com/BTMuli/TeyvatGuide',
#  'https://github.com/Levminer/cores',
#  'https://github.com/breadthe/seismic',
#  'https://github.com/awkj/stockman',
#  'https://github.com/lifecoder1988/tauri-watch-coin',
#  'https://github.com/meel-hd/japanese',
#  'https://github.com/oguzkaganeren/manjaro-starter',
#  'https://github.com/ZaneH/piano-trainer',
#  'https://github.com/hiltontj/solars',
#  'https://github.com/syre-data/syre',
#  'https://github.com/Roseblume/Rosary',
#  'https://github.com/clash-verge-rev/clash-verge-rev',
#  'https://github.com/vicanso/cyberapi',
#  'https://github.com/jexpe-apps/jexpe',
#  'https://github.com/samirdjelal/mail-dev',
#  'https://github.com/nhexirc/nhex',
#  'https://github.com/rustdesk/rustdesk-server',
#  'https://github.com/thewh1teagle/RustDuck',
#  'https://github.com/TheBlindM/T-Shell',
#  'https://github.com/TunnlTo/desktop-app',
#  'https://github.com/upvpn/upvpn-app',
#  'https://github.com/windht/watcher',
#  'https://github.com/stefanodevenuto/wirefish',
#  'https://github.com/samirdjelal/bidirectional',
#  'https://github.com/FPurchess/blank',
#  'https://github.com/BigIskander/Handwriting-keyboard-for-Linux-tesseract',
#  'https://github.com/ahmedkapro/journalv',
#  'https://github.com/drl990114/MarkFlowy',
#  'https://github.com/ruralad/notedown',
#  'https://github.com/tywil04/parchment',
#  'https://github.com/opensourcecheemsburgers/ubiquity',
#  'https://github.com/HubertK05/banban',
#  'https://github.com/rajatkulkarni95/buildlog',
#  'https://github.com/GHGHGHKO/dalgona',
#  'https://github.com/mikaelkristiansson/gitbar',
#  'https://github.com/Gitification-App/gitification',
#  'https://github.com/codad5/google-task-tauri',
#  'https://github.com/trobonox/kanri',
#  'https://github.com/zxh3/kianalol',
#  'https://github.com/Brendonovich/macrograph',
#  'https://github.com/Gnarus-G/mynd',
#  'https://github.com/mrjackwills/obliqoro',
#  'https://github.com/PasteBar/PasteBarApp',
#  'https://github.com/g07cha/pomodoro',
#  'https://github.com/probablykasper/remind-me-again',
#  'https://github.com/jam53/Takma',
#  'https://github.com/SeakMengs/WindowPet',
#  'https://github.com/harana/search',
#  'https://github.com/a5huynh/spyglass',
#  'https://github.com/Levminer/authme',
#  'https://github.com/OneKeePass/desktop',
#  'https://github.com/padloc/padloc',
#  'https://github.com/Raspirus/Raspirus',
#  'https://github.com/kunalsin9h/secops',
#  'https://github.com/pwltr/tauthy',
#  'https://github.com/fosslife/truthy/',
#  'https://github.com/SpikeHD/Dorion',
#  'https://github.com/iohzrd/identia',
#  'https://github.com/probablykasper/kadium',
#  'https://github.com/dhextras/age-timer-tauri',
#  'https://github.com/auto-wallpaper/auto-wallpaper',
#  'https://github.com/bewcloud/bewcloud-desktop',
#  'https://github.com/dunkbing/typeview',
#  'https://github.com/billyjacoby/browsernaut',
#  'https://github.com/lesterhnu/clipboard',
#  'https://github.com/0-don/clippy',
#  'https://github.com/SticksDev/FanslySync',
#  'https://github.com/spieglt/flyingcarpet',
#  'https://github.com/thewh1teagle/happy',
#  'https://github.com/KittyCAD/modeling-app',
#  'https://github.com/dubisdev/key-on-screen',
#  'https://github.com/ChurchTao/Lanaya',
#  'https://github.com/thewh1teagle/lingo',
#  'https://github.com/linka-app/linka',
#  'https://github.com/Akylas/mbview-rs',
#  'https://github.com/ZaneH/metronome',
#  'https://github.com/thewh1teagle/mobslide',
#  'https://github.com/zhanglun/pavo',
#  'https://github.com/kkoomen/pointless',
#  'https://github.com/pot-app/pot-desktop',
#  'https://github.com/RoundedCorners/Application',
#  'https://github.com/dubisdev/runmath',
#  'https://github.com/Nicify/sensi-mouse',
#  'https://github.com/breadthe/sd-buddy',
#  'https://github.com/cablehead/stacks',
#  'https://github.com/s00d/switchshuttle',
#  'https://github.com/sprout2000/tauview',
#  'https://github.com/acarl005/toerings',
#  'https://github.com/openscopeproject/TrguiNG',
#  'https://github.com/ParthJadhav/verve',
#  'https://github.com/zeet2020/wallpaper-changer-tauri',
#  'https://github.com/vitejs/awesome-vite',
#  'https://github.com/sudheerj/vuejs-interview-questions',
#  'https://github.com/vuejs/vue-requests',
#  'https://github.com/sdras/intro-to-vue',
#  'https://github.com/cuixiaorui/mini-vue',
#  'https://github.com/chengpeiquan/learning-vue3',
#  'https://github.com/hypescale/moralis-vue-boilerplate',
#  'https://github.com/brandonjpierce/node-webkit-boilerplate',
#  'https://github.com/superlloyd/VueSamples',
#  'https://github.com/kazupon/vue-router-hackernews',
#  'https://github.com/inca/voie-example',
#  'https://github.com/rajabishek/begin',
#  'https://github.com/BosNaufal/vue-mini-shop',
#  'https://github.com/mul14/vue-soundcloud',
#  'https://github.com/haydenbbickerton/feature-requests-app',
#  'https://github.com/yjj5855/node-vue-server-webpack',
#  'https://github.com/websemantics/strong-together',
#  'https://github.com/sjerrys/vuetest',
#  'https://github.com/gustaYo/ngexplorer-vuejs-client',
#  'https://github.com/BosNaufal/vue-simple-pwa',
#  'https://github.com/aweber1/tour-of-heroes-vue2',
#  'https://github.com/revue/revue',
#  'https://github.com/echoVic/vue-table-pagination',
#  'https://github.com/delay/feathers-vue-blog-admin-demo',
#  'https://github.com/fishenal/Todos_Vuejs',
#  'https://github.com/gustaYo/ngexplorer-quasar',
#  'https://github.com/rstoenescu/quasar-framework',
#  'https://github.com/moonou/zhihu-daily-vue',
#  'https://github.com/qxl1231/generator-loopback-vue',
#  'https://github.com/metricloop/vuex-events-messaging-demo',
#  'https://github.com/akifo/vue-memo',
#  'https://github.com/ChangJoo-Park/Resume-Vue',
#  'https://github.com/mgyongyosi/VuejsSSRSample',
#  'https://github.com/rokups/hello-vue-django',
#  'https://github.com/MarkPieszak/aspnetcore-Vue-starter',
#  'https://github.com/ShuvoHabib/Vue-JSX-and-Vue-Redux-Navigation-Tab',
#  'https://github.com/YuheiNakasaka/vue-twitter-client',
#  'https://github.com/storyblok/vuejs-boilerplate',
#  'https://github.com/Ethaan/vuexpresso',
#  'https://github.com/ndabAP/vue-sails-example',
#  'https://github.com/ErickPetru/vue-feathers-chat',
#  'https://github.com/JackGit/xplan/',
#  'https://github.com/voluntadpear/todomvc-vue-webpack',
#  'https://github.com/gustaYo/vue-chess-storybook',
#  'https://github.com/sdras/vue-weather-notifier',
#  'https://github.com/wmui/vueblog',
#  'https://github.com/Piterden/cinemateka',
#  'https://github.com/rhapsodyn/vue-minesweeper',
#  'https://github.com/OXOYO/X-Flowchart-Vue',
#  'https://github.com/johndatserakis/koa-vue-notes-web',
#  'https://github.com/ittus/vuejs-firebase-shopping-cart',
#  'https://github.com/rchung95/PokedexVueJs',
#  'https://github.com/aofdev/vuefire-auth',
#  'https://github.com/aofdev/vuefire-realtimedatabase',
#  'https://github.com/aofdev/vuefire-storage',
#  'https://github.com/deepak-singh/vue-blog-pwa',
#  'https://github.com/aofdev/vue-firebase-auth-vuex',
#  'https://github.com/joshua1988/vue-chart-starter-kit',
#  'https://github.com/edge/conway',
#  'https://github.com/igeligel/vuex-feature-scoped-structure',
#  'https://github.com/ooade/vuex-examples',
#  'https://github.com/bahmutov/vue-vuex-todomvc',
#  'https://github.com/skysign/vuejs-sqljs-boilerplate',
#  'https://github.com/OXOYO/X-WebDesktop-Vue',
#  'https://github.com/Jamaks/vuejs-music-player',
#  'https://github.com/sarneeh/vuejs-example-stock-trader',
#  'https://github.com/jasscia/one',
#  'https://github.com/DominikAngerer/auth0-vue',
#  'https://github.com/SierraSoftworks/vue-template',
#  'https://github.com/ntkme/vue-relay-examples',
#  'https://github.com/alefesouza/laravel-vue-boilerplate',
#  'https://github.com/viljamis/vue-design-system',
#  'https://github.com/faisaltheparttimecoder/bulma-vuejs-demo-website',
#  'https://github.com/wmhello/laravel_template_with_vue',
#  'https://github.com/PowerDos/Mall-Vue',
#  'https://github.com/elaijuh/fue',
#  'https://github.com/SoftwareAteliers/asp-net-core-vue-starter',
#  'https://github.com/kavalcante/nuxt-element-apollo',
#  'https://github.com/visualjerk/vue-cion-design-system',
#  'https://github.com/alexander-elgin/vue-todo-list',
#  'https://github.com/ModusCreateOrg/ionic-vue-examples/',
#  'https://github.com/justinwash/Client-Side-Vue',
#  'https://github.com/arunredhu/vuejs_boilerplate',
#  'https://github.com/Seokky/vue-snake-game',
#  'https://github.com/cometchat-pro-tutorials/vue-cometchat-one-on-one-chat',
#  'https://github.com/akoidan/vue-webpack-typescript',
#  'https://github.com/acidjazz/laranuxt',
#  'https://github.com/snturk/to',
#  'https://github.com/ooxxro/all-about-me',
#  'https://github.com/blacksonic/todomvc-vue-composition-api',
#  'https://github.com/blacksonic/todomvc-vue',
#  'https://github.com/blacksonic/movie-search-vue',
#  'https://github.com/reiallenramos/nuxtjs-otp-boilerplate',
#  'https://github.com/Morgbn/vuetify-i18n-boilerplate',
#  'https://github.com/wobsoriano/vue-keep',
#  'https://github.com/faisaltheparttimecoder/go-echo-vuejs-boilerplate',
#  'https://github.com/canersevince/Vue-Next-TicTacToe-Game',
#  'https://github.com/snturk/covid19-vue-component',
#  'https://github.com/meschg/vue-stack-cesium',
#  'https://github.com/uicrooks/shopify-theme-lab',
#  'https://github.com/ably-labs/depict-it',
#  'https://github.com/boussadjra/vue3-webpack',
#  'https://github.com/boussadjra/laravel-vue-3-starter',
#  'https://github.com/davidgaroro/vuetify-swipeout',
#  'https://github.com/davidgaroro/vuetify-todo-pwa',
#  'https://github.com/davidgaroro/vue-todo-pwa',
#  'https://github.com/debadeepsen/vuewordgame',
#  'https://github.com/okandas/coinchartsvue',
#  'https://github.com/wobsoriano/vue-cart',
#  'https://github.com/wobsoriano/vuemoji-picker',
#  'https://github.com/maxim-top/maxim-web',
#  'https://github.com/Ted2xmen/vue-cli-3-wave-ui-starter',
#  'https://github.com/coskuncayemre/CVue-Awesome',
#  'https://github.com/TinkoLiu/vue3-ts-lib-template',
#  'https://github.com/daily-demos/vue-call-object',
#  'https://github.com/cerino-ligutom/Vue3-Starter',
#  'https://github.com/devisasari/text-editor-vue-3',
#  'https://github.com/fsgreco/vue3-laravel-api',
#  'https://github.com/gyt95/h5',
#  'https://github.com/antfu/vitesse',
#  'https://github.com/antfu/vitesse-lite',
#  'https://github.com/selimdoyranli/vue-plugin-boilerplate',
#  'https://github.com/pagekit/pagekit',
#  'https://github.com/phanan/koel',
#  'https://github.com/mrgodhani/raven-reader',
#  'https://github.com/Zhangdroid/Gokotta',
#  'https://github.com/misterGF/CoPilot',
#  'https://github.com/pepf/retrospectify',
#  'https://github.com/jade-press/jade-press',
#  'https://github.com/astralapp/astral',
#  'https://github.com/egoist/eme',
#  'https://github.com/SidKwok/github-explorer',
#  'https://github.com/typicode/hotel',
#  'https://github.com/surfbirdapp/surfbird',
#  'https://github.com/approach0/search-engine',
#  'https://github.com/devfake/flox',
#  'https://github.com/samiheikki/javascript-guessing-game',
#  'https://github.com/viko16/vue-ghpages-blog',
#  'https://github.com/Vuedo/vuedo',
#  'https://github.com/pluto1114/vue-music163',
#  'https://github.com/zhangxin840/tomato5',
#  'https://github.com/freearhey/web-learn',
#  'https://github.com/forehalo/materialize-blog',
#  'https://github.com/ChangJoo-Park/vue-component-generator',
#  'https://github.com/super-dev/SDR-News',
#  'https://github.com/jcc/blog',
#  'https://github.com/qazbnm456/lulumi-browser',
#  'https://github.com/bstavroulakis/vue-wordpress-pwa',
#  'https://github.com/koumoul-dev/openapi-viewer',
#  'https://github.com/oguzhaninan/Stacer',
#  'https://github.com/cmllr/distrochooser',
#  'https://github.com/oguzhaninan/Buka',
#  'https://github.com/egoist/docute',
#  'https://github.com/rigor789/nativescript-vue',
#  'https://github.com/fireyy/piper',
#  'https://github.com/lincenying/mmf-blog-vue2',
#  'https://github.com/iutbay/mm',
#  'https://github.com/dyu/bookmarks',
#  'https://github.com/tangram-js/json-schema-editor',
#  'https://github.com/apertureless/npm-stats',
#  'https://github.com/devjin0617/vue2-admin-lte',
#  'https://github.com/dockeron/dockeron',
#  'https://github.com/alicin/flamme',
#  'https://github.com/Caiyeon/goldfish',
#  'https://github.com/alicin/promptie',
#  'https://github.com/clarkdo/hare',
#  'https://github.com/creativetimofficial/vue-paper-dashboard',
#  'https://github.com/otezz/AdminLTE-VueJS2',
#  'https://github.com/lucduong/vue-material-dashboard',
#  'https://github.com/mazipan/explore-github',
#  'https://github.com/coreui/coreui-free-vue-admin-template',
#  'https://github.com/mazipan/chucknorris',
#  'https://github.com/paulschwoerer/leafplayer',
#  'https://github.com/tangram-js/json-editor',
#  'https://github.com/voten-co/voten',
#  'https://github.com/Rud156/News-Weaver',
#  'https://github.com/NoDivide/astrum',
#  'https://github.com/aofdev/vue-pwa-vision',
#  'https://github.com/aofdev/vue-pwa-rekognition',
#  'https://github.com/ammobinDOTca/ammobin-client',
#  'https://github.com/mubaidr/Book-Trading-Club',
#  'https://github.com/mubaidr/vuejs-extension-pack',
#  'https://github.com/Requarks/wiki',
#  'https://github.com/aofdev/vue-pwa-speech',
#  'https://github.com/aofdev/vue-speech-streaming',
#  'https://github.com/limichange/my-animation-list',
#  'https://github.com/aofdev/vue-input-streaming',
#  'https://github.com/eggplanetio/tidytab',
#  'https://github.com/headwirecom/peregrine-cms',
#  'https://github.com/concept-to-clinic/concept-to-clinic',
#  'https://github.com/louisbourque/grid-awesome',
#  'https://github.com/creativetimofficial/vue-light-bootstrap-dashboard',
#  'https://github.com/picocodes/hubaga',
#  'https://github.com/ndro/vue-webpack-buefy',
#  'https://github.com/bkzl/coypu',
#  'https://github.com/skyhark-projects/core-server',
#  'https://github.com/NNTin/discord-logo',
#  'https://github.com/mubaidr/node-vue-template',
#  'https://github.com/DivanteLtd/vue-storefront',
#  'https://github.com/freedomotic/fd-vue-webapp',
#  'https://github.com/cheng-kang/wildfire',
#  'https://github.com/ridereceipts/ridereceipts',
#  'https://github.com/mubaidr/vue-chrome-extension-boilerplate',
#  'https://github.com/MarsZone/TimeMark',
#  'https://github.com/laravel-enso/enso',
#  'https://github.com/lauthieb/code-notes',
#  'https://github.com/Splode/pomotroid',
#  'https://github.com/bradoyler/xmr-miner',
#  'https://github.com/bradoyler/xmr-paper',
#  'https://github.com/sh0cked/joy-proxy',
#  'https://github.com/mubaidr/activity-automation',
#  'https://github.com/generateui/jsettlers-web',
#  'https://github.com/tamiat/tamiat',
#  'https://github.com/vuegg/vuegg',
#  'https://github.com/podlove/podlove-web-player',
#  'https://github.com/kaleguy/leovue',
#  'https://github.com/VeryWow/v-oogle',
#  'https://github.com/tatyshev/pomidorus',
#  'https://github.com/jaywink/socialhome',
#  'https://github.com/herbat73/GenVue',
#  'https://github.com/BlackHole1/vue-array',
#  'https://github.com/laqul/laqul',
#  'https://github.com/v1Labs/protovue',
#  'https://github.com/johndatserakis/chrome-ribbon-reminder',
#  'https://github.com/modularsoftware/genealogy',
#  'https://github.com/vladocar/Minimal-Notes',
#  'https://github.com/serversideup/roastandbrew',
#  'https://github.com/benweet/stackedit/',
#  'https://github.com/14nrv/buefy-shop',
#  'https://github.com/Lt0/sysmon',
#  'https://github.com/DOkwufulueze/eth-vue',
#  'https://github.com/ssshooter/nippon-color',
#  'https://github.com/saleina/SaleinaCMS',
#  'https://github.com/mimecorg/vuido',
#  'https://github.com/ahmetzeybek/YouGet',
#  'https://github.com/wesssel/vue-pug-stylus',
#  'https://github.com/Bartozzz/crypto-news',
#  'https://github.com/Alexays/Epiboard',
#  'https://github.com/zhudyos/duic',
#  'https://github.com/ivanlori/Vuemmerce',
#  'https://github.com/alirizaadiyahsi/Nucleus',
#  'https://github.com/STS-Rosario/carpoolear',
#  'https://github.com/bazzite/statusfy',
#  'https://github.com/Arattian/DynamoDb-GUI-Client',
#  'https://github.com/SnakeyHips/RosterWebApp',
#  'https://github.com/rash0/Vue-Ecom',
#  'https://github.com/Piterden/vue-crossword',
#  'https://github.com/Hoogkamer/vue-org-chart',
#  'https://github.com/ModusCreateOrg/beep',
#  'https://github.com/szczepanmasny/vue-crud',
#  'https://github.com/satriaajiputra/mtodo',
#  'https://github.com/Orogenesis/FireX-Proxy',
#  'https://github.com/silent-lad/VueSolitaire',
#  'https://github.com/qmk/qmk_configurator',
#  'https://github.com/Janglee123/eplee',
#  'https://github.com/gothinkster/vue-realworld-example-app',
#  'https://github.com/dailynowco/daily',
#  'https://github.com/alexusmai/laravel-file-manager',
#  'https://github.com/JayeshLab/vue-crypto-dashboard',
#  'https://github.com/icellmobilsoft/etcdmanager',
#  'https://github.com/MuhaddiMu/Idea-ReVue',
#  'https://github.com/simplyvinay/vue-expenses',
#  'https://github.com/akaunting/akaunting',
#  'https://github.com/vuefront/vuefront',
#  'https://github.com/joon610/mockup-server',
#  'https://github.com/emqx/MQTTX',
#  'https://github.com/akoidan/pychat',
#  'https://github.com/m0g/zeithub',
#  'https://github.com/codecept-js/ui',
#  'https://github.com/Seungwoo321/vue-pivottable',
#  'https://github.com/Seungwoo321/vue-datamaps',
#  'https://github.com/vkaelin/LeagueStats',
#  'https://github.com/Viveckh/Veniqa',
#  'https://github.com/tatoMa/neteast-cloud-music-player',
#  'https://github.com/itsalb3rt/sheiley_shop_app',
#  'https://github.com/itsalb3rt/afterman',
#  'https://github.com/wwwenjie/Movie-Paradise',
#  'https://github.com/dhruvmisra/Pathfinding-Visualizer-ThreeJS',
#  'https://github.com/itsalb3rt/agile-visitors',
#  'https://github.com/Junior-Developer/Pexelry',
#  'https://github.com/yunity/karrot-frontend',
#  'https://github.com/ably-labs/realtime-quiz-framework',
#  'https://github.com/logchimp/logchimp',
#  'https://github.com/joek85/trooveo',
#  'https://github.com/Selfhostedpro/Yacht',
#  'https://github.com/Fabio286/antares',
#  'https://github.com/bagisto/bagisto',
#  'https://github.com/bibhuticoder/samaya',
#  'https://github.com/grandnode/grandnode2/',
#  'https://github.com/aimeos/aimeos',
#  'https://github.com/bourgeoisor/xivtodo',
#  'https://github.com/statickidz/quicktok',
#  'https://github.com/empathyco/x',
#  'https://github.com/betterRunner/context-note',
#  'https://github.com/balancer-labs/frontend-v2',
#  'https://github.com/themeselection/materio-vuetify-vuejs-laravel-admin-template-free',
#  'https://github.com/joek85/NuxTube',
#  'https://github.com/lissy93/dashy',
#  'https://github.com/fairdataihub/FAIRshare',
#  'https://github.com/ymzEmre/vue-birthday-reminder',
#  'https://github.com/anysniper/Frontend',
#  'https://github.com/uros-5/ui-lishuuro',
#  'https://github.com/DaZuiZui/ZuiOJ',
#  'https://github.com/DaZuiZui/Insurance-system',
#  'https://github.com/kaandesu/vue-paho-mqtt',
#  'https://github.com/n1crack/vuefinder',
#  'https://github.com/kaandesu/vite-vue-ultimate-starter',
#  'https://github.com/kaandesu/vue-daisyui-theme-manager',
#  'https://github.com/os-scar/overlay',
#  'https://github.com/haixin-fang/starfish-vue3-lowcode',
#  'https://github.com/rofixro/vue3-realworld-app',
#  'https://github.com/slidevjs/slidev',
#  'https://github.com/qier222/YesPlayMusic',
#  'https://github.com/zyronon/douyin',
#  'https://github.com/mallgroup/mal-mongster',
#  'https://github.com/nxshell/nxshell',
#  'https://github.com/nocodb/nocodb',
#  'https://github.com/kodadot/nft-gallery',
#  'https://github.com/IgorHalfeld/v-notes',
#  'https://github.com/zllovesuki/dermail-webmail',
#  'https://github.com/zllovesuki/slugsurvival',
#  'https://github.com/ChangJoo-Park/gitrelease-app',
#  'https://github.com/JasonBai007/suanban',
#  'https://github.com/KDCinfo/guess-right',
#  'https://github.com/lincenying/mmf-blog-vue2-ssr',
#  'https://github.com/OrangeXC/n2ex',
#  'https://github.com/devjin0617/ripplectron',
#  'https://github.com/rohitpaulk/todoist-tribute/',
#  'https://github.com/dashersw/brain-bits',
#  'https://github.com/NeutroniumCore/CodeDependencyScanner/',
#  'https://github.com/sc0vu/vuethwallet',
#  'https://github.com/sc0Vu/vuethexplore',
#  'https://github.com/znck/keynote',
#  'https://github.com/morkro/happy-plants',
#  'https://github.com/mritunjaygoutam12/Remote-host',
#  'https://github.com/antonreshetov/massCode',
#  'https://github.com/acidjazz/oneconcern',
#  'https://github.com/IanLuan/TodoDev',
#  'https://github.com/gk4m/vue-spotify',
#  'https://github.com/canersevince/Pexies',
#  'https://github.com/konaraddio/web-riimote',
#  'https://github.com/CSSColorVars/csscolorvars',
#  'https://github.com/snturk/thing',
#  'https://github.com/vue-a11y/vue-skip-to',
#  'https://github.com/vue-a11y/vue-axe',
#  'https://github.com/vue-a11y/vue-announcer',
#  'https://github.com/maranran/eslint-plugin-vue-a11y',
#  'https://github.com/theKashey/vue-focus-lock',
#  'https://github.com/IBM/vue-a11y-calendar',
#  'https://github.com/vue-a11y/eslint-plugin-vuejs-accessibility',
#  'https://github.com/quasarframework/quasar',
#  'https://github.com/vuematerial/vue-material',
#  'https://github.com/vuetifyjs/vuetify',
#  'https://github.com/museui/muse-ui',
#  'https://github.com/rafaelpimpa/buefy',
#  'https://github.com/ElemeFE/element',
#  'https://github.com/vouill/vue-bulma-components',
#  'https://github.com/bootstrap-vue/bootstrap-vue',
#  'https://github.com/zircleUI/zircleUI',
#  'https://github.com/matsp/material-components-vue',
#  'https://github.com/material-components/material-components-web',
#  'https://github.com/sudheerj/vueface',
#  'https://github.com/vueComponent/ant-design-vue',
#  'https://github.com/heyui/heyui',
#  'https://github.com/balmjs/balm-ui',
#  'https://github.com/N3-components/N3-components',
#  'https://github.com/designrevision/shards-vue',
#  'https://github.com/SAP/fundamental-vue',
#  'https://github.com/framevuerk/framevuerk',
#  'https://github.com/carbon-design-system/carbon-components-vue',
#  'https://github.com/inkline/inkline/',
#  'https://github.com/Wscats/vue-awesome-mui',
#  'https://github.com/mdbootstrap/Vue-Bootstrap-with-Material-Design',
#  'https://github.com/pgbross/vue-material-adapter',
#  'https://github.com/coreui/coreui-vue',
#  'https://github.com/DaoCloud/dao-style',
#  'https://github.com/chakra-ui/chakra-ui-vue',
#  'https://github.com/loo41/vuc',
#  'https://github.com/oruga-ui/oruga',
#  'https://github.com/antoniandre/wave-ui',
#  'https://github.com/vectrejs/vectre',
#  'https://github.com/kkbjs/element3',
#  'https://github.com/superbvue/SuperBVue',
#  'https://github.com/Qvant-lab/qui',
#  'https://github.com/lecoueyl/mijin',
#  'https://github.com/epicmaxco/vuestic-ui',
#  'https://github.com/Qvant-lab/qui-max',
#  'https://github.com/TuSimple/naive-ui',
#  'https://github.com/element-plus/element-plus',
#  'https://github.com/UngeUI/ungeui',
#  'https://github.com/qmhc/vexip-ui',
#  'https://github.com/jd-solanki/anu',
#  'https://github.com/patrickcate/vue-uswds',
#  'https://github.com/ManukMinasyan/stellar-ui',
#  'https://github.com/radix-vue/shadcn-vue',
#  'https://github.com/shadcn-ui/ui',
#  'https://github.com/radix-vue/radix-vue',
#  'https://github.com/tailwindlabs/tailwindcss',
#  'https://github.com/framework7io/framework7',
#  'https://github.com/airyland/vux',
#  'https://github.com/OnsenUI/OnsenUI',
#  'https://github.com/bmfe/eros-template',
#  'https://github.com/ionic-team/ionic-framework',
#  'https://github.com/nativescript-vue/nativescript-vue',
#  'https://github.com/GeekyAnts/vue-native-core',
#  'https://github.com/dcloudio/uni-app',
#  'https://github.com/ElemeFE/mint-ui',
#  'https://github.com/youzan/vant',
#  'https://github.com/jdf2e/nutui/',
#  'https://github.com/posva/vue-mdc',
#  'https://github.com/JosephusPaye/Keen-UI',
#  'https://github.com/vue-bulma/vue-admin',
#  'https://github.com/vuikit/vuikit',
#  'https://github.com/uiv-lib/uiv',
#  'https://github.com/wffranco/vue-strap',
#  'https://github.com/chaogao/jsmod-pc-vue',
#  'https://github.com/guilhermewaess/SemVue',
#  'https://github.com/aidewoode/office-ui-fabric-vue',
#  'https://github.com/Semantic-UI-Vue/Semantic-UI-Vue',
#  'https://github.com/lusaxweb/vuesax',
#  'https://github.com/banshee-ui/banshee',
#  'https://github.com/nvms/vue-atlas',
#  'https://github.com/DevExpress/devextreme-vue',
#  'https://github.com/juijs/vue-uix',
#  'https://github.com/LeCoupa/vuedarkmode',
#  'https://github.com/arturmiz/vuent',
#  'https://github.com/dreambo8563/bpit-vue',
#  'https://github.com/alfonsobries/vue-tailwind',
#  'https://github.com/quatrochan/Equal',
#  'https://github.com/mevinoth/slim-ui',
#  'https://github.com/christiankienle/cdk',
#  'https://github.com/tolking/element-pro-components',
#  'https://github.com/TonyLuo/iview-vue-admin',
#  'https://github.com/TonyLuo/element-vue-admin',
#  'https://github.com/PanJiaChen/vue-element-admin',
#  'https://github.com/d2-projects/d2-admin',
#  'https://github.com/wxs77577/rest-admin',
#  'https://github.com/DesignRevision/shards-dashboard-vue',
#  'https://github.com/tookit/vue-material-admin',
#  'https://github.com/codetrial/element-admin',
#  'https://github.com/zce/dashboard',
#  'https://github.com/openfext/vue-admin-next',
#  'https://github.com/boussadjra/vue-pro-sidebar',
#  'https://github.com/BootstrapDash/stellar-admin-vue-free',
#  'https://github.com/epicmaxco/vuestic-admin',
#  'https://github.com/themeselection/materio-vuetify-vuejs-admin-template-free',
#  'https://github.com/otezz/tailmin',
#  'https://github.com/Mani1124/vue-admin-template',
#  'https://github.com/justboil/admin-one-vue-tailwind',
#  'https://github.com/cruip/vuejs-admin-dashboard-template',
#  'https://github.com/cmdparkour/vue-admin-box',
#  'https://github.com/ltv/argon-dashboard-vue3',
#  'https://github.com/kingyue737/vitify-admin',
#  'https://github.com/bit-ocean-studio/dolphin-admin-vue',
#  'https://github.com/vbenjs/vue-vben-admin',
#  'https://github.com/HalseySpicy/Geeker-Admin',
#  'https://github.com/flipped-aurora/gin-vue-admin',
#  'https://github.com/ream/ream',
#  'https://github.com/universal-vue/uvue',
#  'https://github.com/fiction-com/factor',
#  'https://github.com/vuejs/vuepress',
#  'https://github.com/egojump/peco',
#  'https://github.com/saberland/saber',
#  'https://github.com/gridsome/gridsome',
#  'https://github.com/futureaus/servue',
#  'https://github.com/ElMassimo/iles',
#  'https://github.com/vuejs/vitepress',
#  'https://github.com/scriptPilot/app-framework',
#  'https://github.com/myfirebase/myfirebase',
#  'https://github.com/tower1229/Vue-Access-Control',
#  'https://github.com/basys/basys',
#  'https://github.com/zhennann/cabloy',
#  'https://github.com/freakzlike/vue-service-model',
#  'https://github.com/dataformsjs/dataformsjs',
#  'https://github.com/yoychen/v-craft',
#  'https://github.com/KlausSchaefers/vue-low-code',
#  'https://github.com/KlausSchaefers/figma-low-code',
#  'https://github.com/janniks/vue-notion',
#  'https://github.com/vuejs/petite-vue',
#  'https://github.com/MopTym/vue-waterfall',
#  'https://github.com/jbaysolutions/vue-grid-layout',
#  'https://github.com/surmon-china/vue-drag-zone',
#  'https://github.com/shershen08/vue-masonry',
#  'https://github.com/bkzl/vue-fraction-grid',
#  'https://github.com/tangbc/vue-virtual-scroll-list',
#  'https://github.com/Akryum/vue-virtual-scroller',
#  'https://github.com/ddgll/vue-virtualscroll',
#  'https://github.com/rachmanzz/vue-inview',
#  'https://github.com/dattn/dnd-grid',
#  'https://github.com/ktquez/vue-extend-layout',
#  'https://github.com/paulcollett/vue-masonry-css',
#  'https://github.com/starkwang/vue-virtual-collection',
#  'https://github.com/xudafeng/autoresponsive-vue',
#  'https://github.com/SeregPie/VueFlex',
#  'https://github.com/mattrothenberg/vue-grid-styled',
#  'https://github.com/jxnblk/grid-styled/',
#  'https://github.com/anthinkingcoder/simple-grid',
#  'https://github.com/kavalcante/vue-container-component',
#  'https://github.com/alexiscolin/vue-colcade',
#  'https://github.com/arnedesmedt/vue-ads-layout',
#  'https://github.com/imlinus/Vue-Magic-Grid',
#  'https://github.com/venkatperi/vue-splitter-pane',
#  'https://github.com/antoniandre/splitpanes',
#  'https://github.com/promosis/vue-mock-layout',
#  'https://github.com/dreambo8563/vue-simple-drawer',
#  'https://github.com/1000ch/vue-grd',
#  'https://github.com/Guillaume69/vue-masonry-component',
#  'https://github.com/xiaoluoboding/vue-smart-widget',
#  'https://github.com/phphe/vue-colrow',
#  'https://github.com/albertodeago/vue-diagonal',
#  'https://github.com/bensladden/vue-responsive-dash',
#  'https://github.com/fuxingloh/vue-masonry-wall',
#  'https://github.com/fuxingloh/vue-horizontal-list',
#  'https://github.com/leeboyin/vue-layout-system',
#  'https://github.com/harmyderoman/simple-vue-grid',
#  'https://github.com/ilker0/iron-grid-system',
#  'https://github.com/tachibana-shin/vue-re-resizable',
#  'https://github.com/bokuweb/re-resizable',
#  'https://github.com/tachibana-shin/vue-console-feed',
#  'https://github.com/bsssshhhhhhh/vue-typed-virtual-list',
#  'https://github.com/jp-liu/fit-screen',
#  'https://github.com/lhlyu/vue-virtual-waterfall',
#  'https://github.com/chiribuc/vue-stack-grid',
#  'https://github.com/ratiw/vuetable-2',
#  'https://github.com/matfish2/vue-tables-2',
#  'https://github.com/coderdiaz/vue-datasource',
#  'https://github.com/ag-grid/ag-grid',
#  'https://github.com/njleonzhang/vue-data-tables',
#  'https://github.com/tmlee/vue-floatThead',
#  'https://github.com/MicroDroid/vue-materialize-datatable',
#  'https://github.com/xaksis/vue-good-table',
#  'https://github.com/dzwillia/vue-grid',
#  'https://github.com/huangshuwei/vue-easytable',
#  'https://github.com/OneWayTech/vue2-datatable',
#  'https://github.com/euvl/vue-js-grid',
#  'https://github.com/handsontable/vue-handsontable-official',
#  'https://github.com/liqueflies/vue-grid',
#  'https://github.com/VitorLuizC/vue-data-tablee',
#  'https://github.com/richardtallent/vue-scrolling-table',
#  'https://github.com/zollero/el-search-table-pagination',
#  'https://github.com/ais-one/vue-crud-x',
#  'https://github.com/laravel-enso/vuedatatable',
#  'https://github.com/dwqs/v2-table',
#  'https://github.com/future-architect/cheetah-grid',
#  'https://github.com/FEMessage/el-data-table',
#  'https://github.com/arnedesmedt/vue-ads-table-tree',
#  'https://github.com/MarketConnect/vue-pivot-table',
#  'https://github.com/hiendv/teible',
#  'https://github.com/boussadjra/vueye-table',
#  'https://github.com/BernhardtD/vue-sorted-table',
#  'https://github.com/rubanraj54/vue-bootstrap4-table',
#  'https://github.com/tochoromero/vuejs-smart-table',
#  'https://github.com/myENA/vue-table',
#  'https://github.com/jamesdruhan/vue-jd-table',
#  'https://github.com/MengFangui/iview-table-page',
#  'https://github.com/FancyGrid/FancyGrid',
#  'https://github.com/TheoXiong/vue-table-dynamic',
#  'https://github.com/Quintetio/vue-quintable',
#  'https://github.com/andrelmlins/vue-grid-responsive',
#  'https://github.com/Parthfaladu/vue-js-datatable',
#  'https://github.com/jiahengaa/BeeGridTable',
#  'https://github.com/revolist/vue-datagrid',
#  'https://github.com/iendeavor/element-ui-sticky-table',
#  'https://github.com/kouts/vue-dataset',
#  'https://github.com/jeremyjone/jz-gantt',
#  'https://github.com/HC200ok/vue3-easy-data-table',
#  'https://github.com/HELMAB/lv2-datatable',
#  'https://github.com/jiangfei5945/el-col-group',
#  'https://github.com/tanstack/table',
#  'https://github.com/webdevnerdstuff/vuetify-drilldown-table',
#  'https://github.com/x-extends/vxe-table',
#  'https://github.com/se-panfilov/vue-notifications',
#  'https://github.com/noru/vue-easy-toast',
#  'https://github.com/shakee93/vue-toasted',
#  'https://github.com/happyCoda/vue-notifikation',
#  'https://github.com/euvl/vue-notification',
#  'https://github.com/websmurf/vue2-notify',
#  'https://github.com/cristijora/vue-notifyjs',
#  'https://github.com/chryb/vueup',
#  'https://github.com/ahmed-dinar/vuex-flash',
#  'https://github.com/artemsky/vue-snotify',
#  'https://github.com/PygmySlowLoris/vue-notify-me',
#  'https://github.com/renoguyon/vuejs-noty',
#  'https://github.com/keen-on-design/vue-flash-message',
#  'https://github.com/voerro/vue-notifications',
#  'https://github.com/f3oall/vue-awesome-notifications',
#  'https://github.com/arthurvasconcelos/vue-izitoast',
#  'https://github.com/saivarunk/vue-toastr-2',
#  'https://github.com/CodeSeven/toastr',
#  'https://github.com/zerodois/vue-snack',
#  'https://github.com/mengdu/m-message',
#  'https://github.com/Carrene/vue-notification-bell',
#  'https://github.com/marverix/v-tostini',
#  'https://github.com/ankurk91/vue-toast-notification',
#  'https://github.com/nandi95/vue-toastify',
#  'https://github.com/Maronato/vue-toastification',
#  'https://github.com/smwbtech/vue-flash-message',
#  'https://github.com/mathieustan/vue-notification',
#  'https://github.com/codebender828/breadstick',
#  'https://github.com/eolant/vuetify-toast-snackbar',
#  'https://github.com/MeForma/vue-toaster',
#  'https://github.com/HELMAB/vue-notification-ui',
#  'https://github.com/Tahul/vue-my-toasts',
#  'https://github.com/kyvg/vue3-notification',
#  'https://github.com/RashadSaleh/vue-global-alert-utility',
#  'https://github.com/smastrom/notivue',
#  'https://github.com/dzwillia/vue-simple-spinner',
#  'https://github.com/f/vue-wait',
#  'https://github.com/Akryum/vue-progress-path',
#  'https://github.com/realdah/vue-blockui',
#  'https://github.com/epicmaxco/epic-spinners',
#  'https://github.com/chenxuan0000/svg-progress-bar',
#  'https://github.com/ankurk91/vue-loading-overlay',
#  'https://github.com/Hokid/vue-loaders',
#  'https://github.com/STUkh/vue-promise-btn',
#  'https://github.com/TonPC64/vue-spinkit',
#  'https://github.com/hussam-m/vue2-form-loading',
#  'https://github.com/biigpongsatorn/vue-element-loading',
#  'https://github.com/anthinkingcoder/tb-skeleton',
#  'https://github.com/Saeris/vue-spinners',
#  'https://github.com/Yangfan2016/vue-yan-progress',
#  'https://github.com/shwilliam/vue-loading-button',
#  'https://github.com/HELMAB/vue-loading',
#  'https://github.com/igaloly/vue-preloaders',
#  'https://github.com/setaman/vue-ellipse-progress',
#  'https://github.com/altrusl/vuesence-cloud-sync-button',
#  'https://github.com/Bot-Academia/Vue-ui-preloader',
#  'https://github.com/MehdiKhoshnevisz/vue-splash',
#  'https://github.com/neelansh15/vue-ultimate-skeleton-cards',
#  'https://github.com/MeForma/vue-wait-for',
#  'https://github.com/egoist/vue-content-loader',
#  'https://github.com/delowardev/vue3-circle-progress',
#  'https://github.com/peterroe/uspin',
#  'https://github.com/Kholid060/vue-heroicons',
#  'https://github.com/sschoger/heroicons-ui',
#  'https://github.com/alex-oleshkevich/vue-tabler-icons',
#  'https://github.com/tabler/tabler-icons',
#  'https://github.com/Renovamen/oh-vue-icons',
#  'https://github.com/egoist/vue-feather-icons',
#  'https://github.com/fengyuanchen/vue-feather',
#  'https://github.com/EOS-uiux-Solutions/eos-icons-vue',
#  'https://github.com/EOS-uiux-Solutions/eos-icons-vue2',
#  'https://github.com/aykutkardas/vue-icomoon',
#  'https://github.com/kalimah-apps/vue-icons',
#  'https://github.com/mahdikhashan/veemoji',
#  'https://github.com/YishaiBerg/vue-dynamic-marquee',
#  'https://github.com/megasanjay/vue3-marquee',
#  'https://github.com/zeratulmdq/vue-accordion',
#  'https://github.com/euvl/vue-js-dropdown',
#  'https://github.com/vouill/vue-slideout',
#  'https://github.com/Mango/slideout',
#  'https://github.com/AshleyLv/vue-quick-menu',
#  'https://github.com/michitaro/vue-menu',
#  'https://github.com/classicalconditioning/vue-router-nav',
#  'https://github.com/hjl19911127/vue-drawer-layout',
#  'https://github.com/RGRU/vue-simple-menu',
#  'https://github.com/MisRob/vue-tree-navigation',
#  'https://github.com/borisbutenko/bp-vuejs-dropdown',
#  'https://github.com/Lunrtick/vue-bulma-accordion',
#  'https://github.com/TerryZ/v-selectmenu',
#  'https://github.com/mbj36/vue-burger-menu',
#  'https://github.com/JonathanDn/vue-dropdown',
#  'https://github.com/johndatserakis/vue-navigation-bar',
#  'https://github.com/romainsimon/vue-simple-search-dropdown',
#  'https://github.com/Innologica/vue-dropdown-menu',
#  'https://github.com/Dimon24021993/vue-menu-aim',
#  'https://github.com/Alexeykhr/vue-stripe-menu',
#  'https://github.com/VitorLuizC/vue-burger-button',
#  'https://github.com/satriaajiputra/sidebar-menu-drawer',
#  'https://github.com/motla/vue-file-toolbar-menu',
#  'https://github.com/RadKod/v-dropdown-menu',
#  'https://github.com/webzlodimir/vue-bottom-sheet',
#  'https://github.com/storinka/dropdown',
#  'https://github.com/amirkian007/vue-awesome-sidebar',
#  'https://github.com/smastrom/vue-use-fixed-header',
#  'https://github.com/manju16832003/v-minusplusinput',
#  'https://github.com/Keiwen/vue-integer-plusminus',
#  'https://github.com/JayeshLab/vue-numeric-input',
#  'https://github.com/shhdgit/vue-easy-slider',
#  'https://github.com/lsycxyj/vue-l-carousel',
#  'https://github.com/surmon-china/vue-awesome-swiper',
#  'https://github.com/vue-bulma/lory',
#  'https://github.com/staskjs/vue-slick',
#  'https://github.com/drewjbartlett/vue-flickity',
#  'https://github.com/wlada/vue-carousel-3d',
#  'https://github.com/SSENSE/vue-carousel',
#  'https://github.com/OrangeXC/vue-coverflow',
#  'https://github.com/lukaszflorczak/vue-agile',
#  ...]
